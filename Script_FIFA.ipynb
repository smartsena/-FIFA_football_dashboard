# %% [markdown]
# # Imports

# %%
import pandas as pd
from datetime import datetime

# %%
def find_max(nums):
    max_num = float("-inf") # smaller than all other numbers
    for num in nums:
        if num > max_num:
            print(num, "Fill in the missing line here")
    return max_num

# %%
find_max(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 find_max(10)
#
# Cell In[2], line 3, in find_max(nums)
#       1 def find_max(nums):
#       2     max_num = float("-inf") # smaller than all other numbers
# ----> 3     for num in nums:
#       4         if num > max_num:
#       5             print(num, "Fill in the missing line here")
#
# TypeError: 'int' object is not iterable

# %%
# # streamlit run Dashboard_Food_Dellivery.py
# # python Dashboard_Food_Dellivery.py
# pip install streamlit
# pip install pandas
# pip install folium
# pip install haversine

# https://www.kaggle.com/code/paulluo/fifa-analysis/notebook

# %% [markdown]
# # FIFA

# %%
# df_data = pd.read_csv("datasets/CLEAN_FIFA23_official_data.csv", encoding="utf8", index_col=0)
df_data = pd.read_csv("datasets/CLEAN_FIFA23_official_data.csv", index_col=0)

# %%
df[df["Club"] == "Inter"]
# Out:
#            ID                Name  Age  \
# 4      224232          N. Barella   25
# 24     216352         M. Brozović   29
# 42     181872         22 A. Vidal   34
# 49     223697           R. Gosens   27
# 81     208128       H. Çalhanoğlu   28
# 95     231478         L. Martínez   24
# 171    192883       H. Mkhitaryan   33
# 266    226268          F. Dimarco   24
# 395    233096         D. Dumfries   26
# 540    192505           R. Lukaku   29
# 716    198946       D. D'Ambrosio   33
# 777    184392          M. Darmian   32
# 911    212823  20 Gabriel Barbosa   22
# 1042   215330           J. Correa   27
# 1136   180930            E. Džeko   36
# 1215   212153      R. Gagliardini   28
# 1623   175254       22 F. Caicedo   32
# 1826   237383          A. Bastoni   23
# 1958   264699          K. Asllani   20
# 2013   229148             Dalbert   28
# 2031     1041       14 J. Zanetti   39
# 2042   198176          S. de Vrij   30
# 2183   232363         M. Škriniar   27
# ...

# %%
df = df_data
df
# Out:
#            ID             Name  Age  \
# 0      209658      L. Goretzka   27
# 1      212198  Bruno Fernandes   27
# 2      224334         M. Acuña   30
# 3      192985     K. De Bruyne   31
# 4      224232       N. Barella   25
# ...       ...              ...  ...
# 17655  269526    Deng Xiongtao   19
# 17656  267946   22 Lim Jun Sub   17
# 17657  270567         A. Demir   25
# 17658  256624     21 S. Czajor   18
# 17659  256376  21 F. Jakobsson   20
#
#                                                   Photo     Nationality  \
# 0      https://cdn.sofifa.net/players/209/658/23_60.png         Germany
# 1      https://cdn.sofifa.net/players/212/198/23_60.png        Portugal
# 2      https://cdn.sofifa.net/players/224/334/23_60.png       Argentina
# 3      https://cdn.sofifa.net/players/192/985/23_60.png         Belgium
# 4      https://cdn.sofifa.net/players/224/232/23_60.png           Italy
# ...                                                 ...             ...
# ...

# %%
# Contrato válido até uma data futura a data de hoje
df = df[df["Contract Valid Until"] >= datetime.today().year]

# %%
# Contratos com valores maior que 0
# Separa os melhores jogadores esta análise
df = df[df["Value(£)"] > 0]

# %%
# Ordenar pelos melhores jogadores
df = df.sort_values(by="Overall", ascending=False)

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_11',
#  '_17',
#  '_33',
#  '_5',
#  '_6',
#  '_7',
#  '_8',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'datetime',
#  'df',
#  'df2',
#  'df_data',
#  'exit',
#  'fifa2023',
#  'get_ipython',
#  'open',
#  'pd',
#  'quit',
#  'v1',
#  'v2',
#  'v3',
#  'var',
#  'var2019',
#  'year_dataset']

# %%
# locals().items('var2019')
dir(locals().items)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__text_signature__']

# %% [markdown]
# ## Tratamento do DataSet

# %%
# Merge the data
merged_data = pd.concat([fifa17,fifa18,fifa19,fifa20,fifa21,fifa22])
merged_data['Age_in_2026'] = merged_data['Age'] + (2026 - merged_data['Year'])
merged_data

# %% [markdown]
# # Análise

# %%
# clubs = df["Club"].value_counts().reset_index()
clubs = df["Club"].value_counts().index
print(type(clubs))
clubs
# Out:
# <class 'pandas.core.indexes.base.Index'>
# Index(['Manchester United', 'Arsenal', 'Leeds United', 'Paris Saint-Germain',
#        'FC Barcelona', 'Tottenham Hotspur', 'Atalanta', 'Aston Villa',
#        'Sevilla FC', 'Roma',
#        ...
#        'BB Erzurumspor', 'SK Brann', 'USL Dunkerque', 'K Beerschot VA',
#        'Metropolitanos de Caracas FC', 'Oita Trinita', 'Oldham Athletic',
#        'Avispa Fukuoka', 'FC Viktoria 1889 Berlin', 'Southend United'],
#       dtype='object', name='Club', length=806)

# %%
df.loc[df["Name"] == "Marquinhos", :]
# Out:
#           ID        Name  Age  \
# 318   207865  Marquinhos   28
# 4829  270390  Marquinhos   19
# 3860  256614  Marquinhos   22
# 7692  270478  Marquinhos   25
#
#                                                  Photo Nationality  \
# 318   https://cdn.sofifa.net/players/207/865/23_60.png      Brazil
# 4829  https://cdn.sofifa.net/players/270/390/23_60.png      Brazil
# 3860  https://cdn.sofifa.net/players/256/614/23_60.png      Brazil
# 7692  https://cdn.sofifa.net/players/270/478/23_60.png      Brazil
#
#                                      Flag  Overall  Potential  \
# 318   https://cdn.sofifa.net/flags/br.png       88         90
# 4829  https://cdn.sofifa.net/flags/br.png       73         86
# 3860  https://cdn.sofifa.net/flags/br.png       69         79
# 7692  https://cdn.sofifa.net/flags/br.png       67         70
#
#                      Club                                   Club Logo  ...  \
# 318   Paris Saint-Germain      https://cdn.sofifa.net/teams/73/30.png  ...
# ...

# %%
club='Arsenal'
df_players = df[df['Club'] == club]
player = df['Name'].value_counts().index

print(df_players.count())
print(player)
# Out:
# ID                          31
# Name                        31
# Age                         31
# Photo                       31
# Nationality                 31
# Flag                        31
# Overall                     31
# Potential                   31
# Club                        31
# Club Logo                   31
# Value(£)                    31
# Wage(£)                     31
# Special                     31
# Preferred Foot              31
# International Reputation    31
# Weak Foot                   31
# Skill Moves                 31
# Work Rate                   31
# Body Type                   31
# Real Face                   31
# Position                    31
# Joined                      31
# Loaned From                  0
# Contract Valid Until        31
# Height(cm.)                 31
# Weight(lbs.)                31
# Release Clause(£)           31
# Kit Number                  31
# Best Overall Rating         31
# Year_Joined                 31
# ...

# %%
club='Arsenal'
df.loc[df['Club'] == club, ['Name']]
# Out:
#                      Name
# 213           M. Ødegaard
# 130             T. Partey
# 330         Gabriel Jesus
# 13025         A. Ramsdale
# 247               B. Saka
# 4400              Gabriel
# 258            K. Tierney
# 2628        E. Smith Rowe
# 2566            W. Saliba
# 2514          T. Tomiyasu
# 932               N. Pépé
# 1096             G. Xhaka
# 3815             B. White
# 152          O. Zinchenko
# 1521   Gabriel Martinelli
# 5106           R. Holding
# 15889           M. Turner
# 2316         Fábio Vieira
# 950      A. Sambi Lokonga
# 8042           Pablo Marí
# 797                Cédric
# 4833           E. Nketiah
# 4829           Marquinhos
# 15957        R. Rúnarsson
# 5722      B. Norton-Cuffy
# 5504             M. Azeez
# 9597          22 J. Ideho
# 5600           T. Akinola
# 6712         22 C. Cîrjan
# 6945   22 S. Oulad M'Hand
# 13793          22 A. Kirk

# %%
df_players = df[df['Club'] == club]
players = df_players['Name'].value_counts().index
player = st.sidebar.selectbox('Jogador', players)

df['Name'] == player

# %%
player = 'Marquinhos'
df[df["Name"] == player]
# Out:
#           ID        Name  Age  \
# 318   207865  Marquinhos   28
# 4829  270390  Marquinhos   19
# 3860  256614  Marquinhos   22
# 7692  270478  Marquinhos   25
#
#                                                  Photo Nationality  \
# 318   https://cdn.sofifa.net/players/207/865/23_60.png      Brazil
# 4829  https://cdn.sofifa.net/players/270/390/23_60.png      Brazil
# 3860  https://cdn.sofifa.net/players/256/614/23_60.png      Brazil
# 7692  https://cdn.sofifa.net/players/270/478/23_60.png      Brazil
#
#                                      Flag  Overall  Potential  \
# 318   https://cdn.sofifa.net/flags/br.png       88         90
# 4829  https://cdn.sofifa.net/flags/br.png       73         86
# 3860  https://cdn.sofifa.net/flags/br.png       69         79
# 7692  https://cdn.sofifa.net/flags/br.png       67         70
#
#                      Club                                   Club Logo  ...  \
# 318   Paris Saint-Germain      https://cdn.sofifa.net/teams/73/30.png  ...
# ...

# %%
dff = df[df["Name"] == player]
dff = dff[dff["Club"] == club]
dff
# Out:
#           ID        Name  Age  \
# 4829  270390  Marquinhos   19
#
#                                                  Photo Nationality  \
# 4829  https://cdn.sofifa.net/players/270/390/23_60.png      Brazil
#
#                                      Flag  Overall  Potential     Club  \
# 4829  https://cdn.sofifa.net/flags/br.png       73         86  Arsenal
#
#                                   Club Logo  ...  Position      Joined  \
# 4829  https://cdn.sofifa.net/teams/1/30.png  ...       RES  2022-07-01
#
#       Loaned From Contract Valid Until  Height(cm.)  Weight(lbs.)  \
# 4829          NaN               2026.0        183.0       169.785
#
#       Release Clause(£) Kit Number Best Overall Rating Year_Joined
# 4829         17700000.0       27.0                 0.0        2022
#
# [1 rows x 30 columns]

# %%
player = 'Marquinhos'
df[df["Name"] == player].iloc[0]
# Out:
# ID                                                                    207865
# Name                                                              Marquinhos
# Age                                                                       28
# Photo                       https://cdn.sofifa.net/players/207/865/23_60.png
# Nationality                                                           Brazil
# Flag                                     https://cdn.sofifa.net/flags/br.png
# Overall                                                                   88
# Potential                                                                 90
# Club                                                     Paris Saint-Germain
# Club Logo                             https://cdn.sofifa.net/teams/73/30.png
# Value(£)                                                          92000000.0
# Wage(£)                                                             170000.0
# ...
